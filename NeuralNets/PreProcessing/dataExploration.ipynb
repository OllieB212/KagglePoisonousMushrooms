# %% [markdown]
# # Poisenous Mushroom Dataset:

# %% [markdown]
# ## Imports:

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
dfTrain= pd.read_csv('../RawData/train.csv',index_col='id')
dfTest= pd.read_csv('../RawData/test.csv',index_col='id')

# %%
display(dfTrain)
# Out:
#         class  cap-diameter cap-shape cap-surface cap-color  \
# id
# 0           e          8.80         f           s         u
# 1           p          4.51         x           h         o
# 2           e          6.94         f           s         b
# 3           e          3.88         f           y         g
# 4           e          5.85         x           l         w
# ...       ...           ...       ...         ...       ...
# 3116940     e          9.29         f         NaN         n
# 3116941     e         10.88         s         NaN         w
# 3116942     p          7.82         x           e         e
# 3116943     e          9.45         p           i         n
# 3116944     p          3.20         x           s         g
#
#         does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# id
# 0                          f               a            c          w
# 1                          f               a            c          n
# ...

# %%
display(dfTest)
# Out:
#          cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# id
# 3116945          8.64         x         NaN         n                    t
# 3116946          6.90         o           t         o                    f
# 3116947          2.00         b           g         n                    f
# 3116948          3.47         x           t         n                    f
# 3116949          6.17         x           h         y                    f
# ...               ...       ...         ...       ...                  ...
# 5194904          0.88         x           g         w                    f
# 5194905          3.12         x           s         w                    f
# 5194906          5.73         x           e         e                    f
# 5194907          5.03         b           g         n                    f
# 5194908         15.51         f         NaN         w                    f
#
# ...

# %% [markdown]
# ## Graphs:

# %% [markdown]
# ### Pair Plot:

# %%
sns.pairplot(dfTrain,hue='class')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 sns.pairplot(dfTrain,hue='class')
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:2177, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2175 # Add a legend
#    2176 if hue is not None:
# -> 2177     grid.add_legend()
#    2179 grid.tight_layout()
#    2181 return grid
#
# File c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:203, in Grid.add_legend(self, legend_data, title, label_order, adjust_subtitles, **kwargs)
#     200 self._figure.set_size_inches(fig_width + legend_width, fig_height)
#     202 # Draw the plot again to get the new transformations
# --> 203 _draw_figure(self._figure)
# ...

# %% [markdown]
# ### Class Imbalance:

# %%
counts=dfTrain['class'].value_counts()
plt.pie(counts.values,labels=counts.index,autopct='%1.1f%%')
plt.legend()
plt.title('class:')
plt.show()

# %%
sns.histplot(data=dfTrain, x='cap-diameter',hue='class')
plt.title('cap-diameter:')
plt.show()

# %%
print(dfTrain['cap-shape'].value_counts())
sns.countplot(data=dfTrain,x='cap-shape',hue='class')
plt.title('cap-shape')
plt.show()
# Out:
# x        1436026
# f         676238
# s         365146
# b         318646
# o         108835
#           ...
# 12.62          1
# 5.15           1
# 19.04          1
# 49.21          1
# 19.06          1
# Name: cap-shape, Length: 74, dtype: int64

# %%
print(dfTrain['cap-surface'].value_counts())
sns.countplot(data=dfTrain,x='cap-surface',hue='class')
plt.title('cap-surface')
plt.show()
# Out:
# t        460777
# s        384970
# y        327826
# h        284460
# g        263729
#           ...
# 1.42          1
# has h         1
# 10.83         1
# 8.96          1
# 0.87          1
# Name: cap-surface, Length: 83, dtype: int64

# %%
print(dfTrain['cap-color'].value_counts())
sns.countplot(data=dfTrain,x='cap-color',hue='class')
plt.title('cap-color')
plt.show()
# Out:
# n             1359542
# y              386627
# w              379442
# g              210825
# e              197290
#                ...
# 3.95                1
# 6.59                1
# 5.25                1
# veil-color          1
# 9.02                1
# Name: cap-color, Length: 78, dtype: int64

# %%
print(dfTrain['does-bruise-or-bleed'].value_counts())
sns.countplot(data=dfTrain,x='does-bruise-or-bleed',hue='class')
plt.title('does-bruise-or-bleed')
plt.show()
# Out:
# f           2569743
# t            547085
# w                14
# c                11
# h                 9
# a                 7
# b                 7
# x                 7
# y                 7
# k                 6
# s                 6
# e                 4
# l                 4
# p                 4
# d                 4
# g                 3
# z                 3
# o                 3
# i                 2
# n                 2
# r                 1
# has-ring          1
# 3.43              1
# 4.42              1
# 2.9               1
# u                 1
# Name: does-bruise-or-bleed, dtype: int64

# %%
print(dfTrain['gill-attachment'].value_counts())
sns.countplot(data=dfTrain,x='gill-attachment',hue='class')
plt.title('gill-attachment')
plt.show()
# Out:
# a        646034
# d        589236
# x        360878
# e        301858
# s        295439
#           ...
# 1             1
# is a          1
# 3.71          1
# 50.44         1
# 13.94         1
# Name: gill-attachment, Length: 78, dtype: int64

# %%
print(dfTrain['gill-spacing'].value_counts())
sns.countplot(data=dfTrain,x='gill-spacing',hue='class')
plt.title('gill-spacing')
plt.show()
# Out:
# c              1331054
# d               407932
# f               119380
# e                   24
# a                   17
# s                   16
# b                   12
# x                    8
# t                    8
# p                    7
# k                    4
# g                    4
# l                    3
# h                    3
# r                    2
# 6.67                 2
# y                    2
# 0                    2
# 3.81                 1
# 1.6                  1
# n                    1
# 1.88                 1
# does f               1
# 4.09                 1
# 1.36                 1
# 3.24                 1
# 5.55                 1
# 5.42                 1
# 5.7                  1
# 3.62                 1
# 6.4                  1
# 24.38                1
# 12.27                1
# 1                    1
# cap-surface          1
# w                    1
# 3.57                 1
# i                    1
# 0.73                 1
# 4.04                 1
# ...

# %%
print(dfTrain['gill-color'].value_counts())
sns.countplot(data=dfTrain,x='gill-color',hue='class')
plt.title('gill-color')
plt.show()
# Out:
# w       931538
# n       543386
# y       469464
# p       343626
# g       212164
#          ...
# 9.46         1
# 5.01         1
# 3.4          1
# 17           1
# 8.37         1
# Name: gill-color, Length: 63, dtype: int64

# %%
sns.histplot(data=dfTrain, x='stem-height',hue='class')
plt.title('stem-height:')
plt.show()

# %%
sns.histplot(data=dfTrain, x='stem-width',hue='class')
plt.title('stem-width:')
plt.show()

# %%
print(dfTrain['stem-root'].value_counts())
sns.countplot(data=dfTrain,x='stem-root',hue='class')
plt.title('stem-root')
plt.show()
# Out:
# b                    165801
# s                    116946
# r                     47803
# c                     28592
# f                       597
# d                        24
# y                        14
# g                        12
# w                        12
# p                        12
# k                        11
# t                        10
# l                        10
# n                        10
# x                         9
# i                         8
# u                         8
# a                         7
# e                         6
# o                         5
# m                         4
# h                         4
# z                         2
# 10.87                     1
# 13.03                     1
# 3.49                      1
# spore-print-color         1
# 18.06                     1
# 20.0                      1
# 1.48                      1
# 3.23                      1
# 15.69                     1
# 16.88                     1
# ...

# %%
print(dfTrain['stem-surface'].value_counts())
sns.countplot(data=dfTrain,x='stem-surface',hue='class')
plt.title('stem-surface')
plt.show()
# Out:
# s                       327610
# y                       255500
# i                       224346
# t                       147974
# g                        78080
# k                        73383
# h                        28283
# f                          512
# w                           49
# d                           48
# e                           36
# n                           34
# x                           26
# b                           23
# c                           22
# l                           20
# p                           20
# r                           20
# u                           16
# o                           15
# a                           11
# m                            7
# season                       6
# 0.0                          3
# z                            2
# does-bruise-or-bleed         2
# 5.56                         2
# 10.48                        2
# does s                       1
# 1.03                         1
# ...

# %%
print(dfTrain['stem-color'].value_counts())
sns.countplot(data=dfTrain,x='stem-color',hue='class')
plt.title('stem-color')
plt.show()
# Out:
# w                    1196637
# n                    1003464
# y                     373971
# g                     132019
# o                     111541
# e                     103373
# u                      67017
# p                      54690
# k                      33676
# r                      22329
# l                       9994
# b                       7365
# f                        573
# s                         51
# t                         40
# a                         36
# x                         20
# i                         19
# d                         16
# h                         12
# m                         11
# c                          7
# z                          6
# ring-type                  3
# class                      2
# spore-print-color          2
# is n                       1
# 6.31                       1
# 12.92                      1
# 3.98                       1
# 20.07                      1
# 7.7                        1
# ...

# %%
print(dfTrain['veil-type'].value_counts())
sns.countplot(data=dfTrain,x='veil-type',hue='class')
plt.title('veil-type')
plt.show()
# Out:
# u          159373
# w              11
# a               9
# f               8
# e               8
# b               5
# c               5
# y               4
# k               4
# g               4
# n               3
# s               3
# r               2
# d               2
# p               2
# h               2
# i               2
# l               1
# is None         1
# t               1
# 21.11           1
# 5.94            1
# Name: veil-type, dtype: int64

# %%
print(dfTrain['veil-color'].value_counts())
sns.countplot(data=dfTrain,x='veil-color',hue='class')
plt.title('veil-color')
plt.show()
# Out:
# w       279070
# y        30473
# n        30039
# u        14026
# k        13080
# e         9169
# g           30
# p           23
# r           14
# o           13
# s           11
# a            7
# t            7
# d            6
# i            6
# h            5
# c            4
# f            4
# l            4
# b            3
# z            1
# 8.25         1
# 2.49         1
# 3.32         1
# Name: veil-color, dtype: int64

# %%
print(dfTrain['has-ring'].value_counts())
sns.countplot(data=dfTrain,x='has-ring',hue='class')
plt.title('has-ring')
plt.show()
# Out:
# f             2368820
# t              747982
# r                  16
# h                  13
# c                  11
# l                  11
# s                  11
# p                  11
# g                   8
# z                   6
# e                   6
# x                   5
# m                   4
# y                   3
# d                   3
# k                   2
# o                   2
# n                   2
# f has-ring          1
# i                   1
# 10.3                1
# w                   1
# a                   1
# Name: has-ring, dtype: int64

# %%
print(dfTrain['ring-type'].value_counts())
sns.countplot(data=dfTrain,x='ring-type',hue='class')
plt.title('ring-type')
plt.show()
# Out:
# f                       2477170
# e                        120006
# z                        113780
# l                         73443
# r                         67909
# p                         67678
# g                         63687
# m                          3992
# t                            98
# d                            37
# n                            34
# x                            32
# b                            29
# y                            25
# s                            18
# k                            18
# a                            16
# h                            15
# w                            14
# u                            13
# c                            11
# o                             9
# ring-type                     7
# i                             4
# does f                        3
# season                        3
# 15                            1
# 14                            1
# 2.87                          1
# ...

# %%
print(dfTrain['ring-type'].value_counts())
sns.countplot(data=dfTrain,x='ring-type',hue='class')
plt.title('ring-type')
plt.show()
# Out:
# f                       2477170
# e                        120006
# z                        113780
# l                         73443
# r                         67909
# p                         67678
# g                         63687
# m                          3992
# t                            98
# d                            37
# n                            34
# x                            32
# b                            29
# y                            25
# s                            18
# k                            18
# a                            16
# h                            15
# w                            14
# u                            13
# c                            11
# o                             9
# ring-type                     7
# i                             4
# does f                        3
# season                        3
# 15                            1
# 14                            1
# 2.87                          1
# ...

# %%
print(dfTrain['spore-print-color'].value_counts())
sns.countplot(data=dfTrain,x='spore-print-color',hue='class')
plt.title('spore-print-color')
plt.show()
# Out:
# k             107310
# p              68237
# w              50173
# n              22646
# r               7975
# u               7256
# g               3492
# y                 36
# s                 21
# c                 16
# e                 14
# f                 14
# t                 13
# a                 13
# d                  9
# l                  8
# b                  5
# m                  4
# h                  3
# o                  3
# x                  2
# i                  2
# veil-color         2
# 10 None            1
# 9 None             1
# 2.49               1
# class              1
# 2.62               1
# season             1
# 9.55               1
# 6.36               1
# 4.58               1
# Name: spore-print-color, dtype: int64

# %%
print(dfTrain['habitat'].value_counts())
sns.countplot(data=dfTrain,x='habitat',hue='class')
plt.title('habitat')
plt.show()
# Out:
# d                       2177573
# g                        454908
# l                        171892
# m                        150969
# h                        120137
# w                         18530
# p                         17180
# u                          5264
# e                            55
# s                            52
# n                            41
# t                            40
# r                            38
# y                            34
# a                            34
# k                            31
# c                            26
# b                            18
# o                            12
# f                            11
# i                             7
# x                             5
# z                             5
# habitat                       5
# class                         3
# spore-print-color             3
# ring-type                     2
# 18.35                         1
# 3.68                          1
# ...

# %%
print(dfTrain['season'].value_counts())
sns.countplot(data=dfTrain,x='season',hue='class')
plt.title('season')
plt.show()
# Out:
# a    1543321
# u    1153588
# w     278189
# s     141847
# Name: season, dtype: int64

# %% [markdown]
# ## Examin Missing values:

# %%
display(dfTrain.isna().any())
# Out:
# class                   False
# cap-diameter             True
# cap-shape                True
# cap-surface              True
# cap-color                True
# does-bruise-or-bleed     True
# gill-attachment          True
# gill-spacing             True
# gill-color               True
# stem-height             False
# stem-width              False
# stem-root                True
# stem-surface             True
# stem-color               True
# veil-type                True
# veil-color               True
# has-ring                 True
# ring-type                True
# spore-print-color        True
# habitat                  True
# season                  False
# dtype: bool

# %%
counts=dfTrain.loc[dfTrain['cap-diameter'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values cap-diameter:')
plt.show()
# Out:
# p    3
# e    1
# Name: class, dtype: int64

# %% [markdown]
# KNN imputation for cap-diameter

# %%
counts=dfTrain.loc[dfTrain['cap-shape'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values cap-shape:')
plt.show()
# Out:
# p    27
# e    13
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['cap-surface'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values cap-surface:')
plt.show()
# Out:
# p    344790
# e    326233
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['cap-color'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values cap-color:')
plt.show()
# Out:
# e    9
# p    3
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['does-bruise-or-bleed'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values does-bruise-or-bleed:')
plt.show()
# Out:
# e    5
# p    3
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['gill-attachment'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values gill-attachment:')
plt.show()
# Out:
# p    334780
# e    189156
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['gill-spacing'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values gill-spacing:')
plt.show()
# Out:
# p    718366
# e    540069
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['gill-color'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values gill-color:')
plt.show()
# Out:
# p    30
# e    27
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['stem-root'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values stem-root:')
plt.show()
# Out:
# p    1488590
# e    1268433
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['stem-surface'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values stem-surface:')
plt.show()
# Out:
# p    1015506
# e     965355
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['stem-color'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values stem-color:')
plt.show()
# Out:
# e    21
# p    17
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['veil-type'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values veil-type:')
plt.show()
# Out:
# p    1600869
# e    1356624
# Name: class, dtype: int64

# %%
counts=dfTrain['veil-type'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('non-NaN values veil-type:')
plt.show()
# Out:
# u          159373
# w              11
# a               9
# f               8
# e               8
# b               5
# c               5
# y               4
# k               4
# g               4
# n               3
# s               3
# r               2
# d               2
# p               2
# h               2
# i               2
# l               1
# is None         1
# t               1
# 21.11           1
# 5.94            1
# Name: veil-type, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['veil-type'].notna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('non-NaN values veil-type:')
plt.show()
# Out:
# p    104527
# e     54925
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['veil-color'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values veil-color:')
plt.show()
# Out:
# p    1498399
# e    1242548
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['has-ring'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values has-ring:')
plt.show()
# Out:
# e    12
# p    12
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['ring-type'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values ring-type:')
plt.show()
# Out:
# e    77945
# p    50935
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['spore-print-color'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values spore-print-color:')
plt.show()
# Out:
# p    1507638
# e    1342044
# Name: class, dtype: int64

# %%
counts=dfTrain.loc[dfTrain['habitat'].isna(),'class'].value_counts()
display(counts)
plt.pie(counts,labels=counts.index,autopct='%1.1f%%')
plt.title('NaN values habitat:')
plt.show()
# Out:
# p    23
# e    22
# Name: class, dtype: int64

# %%
display(dfTrain.isna().any())
display(dfTest.isna().any())
# Out:
# class                   False
# cap-diameter             True
# cap-shape                True
# cap-surface              True
# cap-color                True
# does-bruise-or-bleed     True
# gill-attachment          True
# gill-spacing             True
# gill-color               True
# stem-height             False
# stem-width              False
# stem-root                True
# stem-surface             True
# stem-color               True
# veil-type                True
# veil-color               True
# has-ring                 True
# ring-type                True
# spore-print-color        True
# habitat                  True
# season                  False
# dtype: bool
# cap-diameter             True
# cap-shape                True
# cap-surface              True
# cap-color                True
# does-bruise-or-bleed     True
# gill-attachment          True
# gill-spacing             True
# gill-color               True
# stem-height              True
# ...
